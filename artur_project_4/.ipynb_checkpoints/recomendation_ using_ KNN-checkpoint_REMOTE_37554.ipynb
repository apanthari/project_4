# %%
# import dependencies 
import pandas as pd
import numpy as np


import warnings
warnings.filterwarnings("ignore")

# %%
#reading data
song_data = pd.read_csv('../data/song_data.csv') 
song_info = pd.read_csv('../data/song_info.csv')

# %%
song_data.head()
# Out:
#                     song_name  song_popularity  song_duration_ms  \
# 0  Boulevard of Broken Dreams               73            262333
# 1                  In The End               66            216933
# 2           Seven Nation Army               76            231733
# 3                  By The Way               74            216933
# 4           How You Remind Me               56            223826
#
#    acousticness  danceability  energy  instrumentalness  key  liveness  \
# 0      0.005520         0.496   0.682          0.000029    8    0.0589
# 1      0.010300         0.542   0.853          0.000000    3    0.1080
# 2      0.008170         0.737   0.463          0.447000    0    0.2550
# 3      0.026400         0.451   0.970          0.003550    0    0.1020
# 4      0.000954         0.447   0.766          0.000000   10    0.1130
#
#    loudness  audio_mode  speechiness    tempo  time_signature  audio_valence
# 0    -4.095           1       0.0294  167.060               4          0.474
# 1    -6.407           0       0.0498  105.256               4          0.370
# 2    -7.828           1       0.0792  123.881               4          0.324
# 3    -4.938           1       0.1070  122.444               4          0.198
# 4    -5.065           1       0.0313  172.011               4          0.574

# %%
song_info.head(10)
# Out:
#                     song_name            artist_name  \
# 0  Boulevard of Broken Dreams              Green Day
# 1                  In The End            Linkin Park
# 2           Seven Nation Army      The White Stripes
# 3                  By The Way  Red Hot Chili Peppers
# 4           How You Remind Me             Nickelback
# 5            Bring Me To Life            Evanescence
# 6                 Last Resort             Papa Roach
# 7    Are You Gonna Be My Girl                    Jet
# 8              Mr. Brightside            The Killers
# 9                 Sex on Fire          Kings of Leon
#
#                           album_names          playlist
# 0  Greatest Hits: God's Favorite Band  00s Rock Anthems
# 1                       Hybrid Theory  00s Rock Anthems
# 2                            Elephant  00s Rock Anthems
# 3         By The Way (Deluxe Version)  00s Rock Anthems
# 4                      Silver Side Up  00s Rock Anthems
# 5                              Fallen  00s Rock Anthems
# 6                              Infest  00s Rock Anthems
# 7                            Get Born  00s Rock Anthems
# 8                            Hot Fuss  00s Rock Anthems
# 9                   Only By The Night  00s Rock Anthems

# %%
song_info[song_info['song_name'] == 'Last Resort']
# Out:
#         song_name artist_name album_names           playlist
# 6     Last Resort  Papa Roach      Infest   00s Rock Anthems
# 8443  Last Resort  Papa Roach      Infest  Hard Rock Workout

# %%
#Convert all string  to lower case
song_info['playlist'] = song_info['playlist'].str.lower()
song_info['song_name'] = song_info['song_name'].str.lower()
song_info['artist_name'] = song_info['artist_name'].str.lower()
song_info['album_names'] = song_info['album_names'].str.lower()
song_data['song_name'] = song_data['song_name'].str.lower()

# %%
# Merging the two datasets into one
song_df = song_data.copy()
song_df['artist_name'] = song_info['artist_name']

#droping duplicates
song_df = song_df.drop_duplicates(subset=['song_name','artist_name'])
song_info = song_info.drop_duplicates(subset=['song_name','artist_name'])

# reset index 
song_df = song_df.reset_index()
song_df = song_df.drop('index',axis=1)

song_df.head()
# Out:
#                     song_name  song_popularity  song_duration_ms  \
# 0  boulevard of broken dreams               73            262333
# 1                  in the end               66            216933
# 2           seven nation army               76            231733
# 3                  by the way               74            216933
# 4           how you remind me               56            223826
#
#    acousticness  danceability  energy  instrumentalness  key  liveness  \
# 0      0.005520         0.496   0.682          0.000029    8    0.0589
# 1      0.010300         0.542   0.853          0.000000    3    0.1080
# 2      0.008170         0.737   0.463          0.447000    0    0.2550
# 3      0.026400         0.451   0.970          0.003550    0    0.1020
# 4      0.000954         0.447   0.766          0.000000   10    0.1130
#
#    loudness  audio_mode  speechiness    tempo  time_signature  audio_valence  \
# 0    -4.095           1       0.0294  167.060               4          0.474
# 1    -6.407           0       0.0498  105.256               4          0.370
# 2    -7.828           1       0.0792  123.881               4          0.324
# 3    -4.938           1       0.1070  122.444               4          0.198
# 4    -5.065           1       0.0313  172.011               4          0.574
#
#              artist_name
# 0              green day
# 1            linkin park
# 2      the white stripes
# 3  red hot chili peppers
# 4             nickelback

# %%
# # check if the numeric features follow normal distribution
# from scipy.stats import shapiro

# stat,p =shapiro(song_df[['song_popularity', 'acousticness',
#        'danceability', 'energy', 'instrumentalness', 'key', 'liveness',
#        'loudness', 'audio_mode', 'speechiness', 'tempo','audio_valence']])

# print("stat: ",stat,":","p :",p)
# if p>0.05:
#     print("normal distribution - fail to reject H0")
# else:
#     print("not normal distribution - reject H0")

# %%
song_df = song_df.drop(['time_signature','song_duration_ms'], axis=1)
song_df.head()
# Out:
#                     song_name  song_popularity  acousticness  danceability  \
# 0  boulevard of broken dreams               73      0.005520         0.496
# 1                  in the end               66      0.010300         0.542
# 2           seven nation army               76      0.008170         0.737
# 3                  by the way               74      0.026400         0.451
# 4           how you remind me               56      0.000954         0.447
#
#    energy  instrumentalness  key  liveness  loudness  audio_mode  speechiness  \
# 0   0.682          0.000029    8    0.0589    -4.095           1       0.0294
# 1   0.853          0.000000    3    0.1080    -6.407           0       0.0498
# 2   0.463          0.447000    0    0.2550    -7.828           1       0.0792
# 3   0.970          0.003550    0    0.1020    -4.938           1       0.1070
# 4   0.766          0.000000   10    0.1130    -5.065           1       0.0313
#
#      tempo  audio_valence            artist_name
# 0  167.060          0.474              green day
# 1  105.256          0.370            linkin park
# 2  123.881          0.324      the white stripes
# 3  122.444          0.198  red hot chili peppers
# 4  172.011          0.574             nickelback

# %%
# Standardise using MinMaxScaler
from sklearn.preprocessing import MinMaxScaler
minmaxscaler = MinMaxScaler()
minmaxscaled = minmaxscaler.fit_transform(song_df[['song_popularity', 'acousticness',
       'danceability', 'energy', 'instrumentalness', 'key', 'liveness',
       'loudness', 'audio_mode', 'speechiness', 'tempo','audio_valence']])
songs_normalized = pd.DataFrame(minmaxscaled, columns=[['song_popularity', 'acousticness',
       'danceability', 'energy', 'instrumentalness', 'key', 'liveness',
       'loudness', 'audio_mode', 'speechiness', 'tempo','audio_valence']])

# %%
song_df_normalized = song_df.copy()
song_df_normalized.head()
# Out:
#                     song_name  song_popularity  acousticness  danceability  \
# 0  boulevard of broken dreams               73      0.005520         0.496
# 1                  in the end               66      0.010300         0.542
# 2           seven nation army               76      0.008170         0.737
# 3                  by the way               74      0.026400         0.451
# 4           how you remind me               56      0.000954         0.447
#
#    energy  instrumentalness  key  liveness  loudness  audio_mode  speechiness  \
# 0   0.682          0.000029    8    0.0589    -4.095           1       0.0294
# 1   0.853          0.000000    3    0.1080    -6.407           0       0.0498
# 2   0.463          0.447000    0    0.2550    -7.828           1       0.0792
# 3   0.970          0.003550    0    0.1020    -4.938           1       0.1070
# 4   0.766          0.000000   10    0.1130    -5.065           1       0.0313
#
#      tempo  audio_valence            artist_name
# 0  167.060          0.474              green day
# 1  105.256          0.370            linkin park
# 2  123.881          0.324      the white stripes
# 3  122.444          0.198  red hot chili peppers
# 4  172.011          0.574             nickelback

# %%
song_df_normalized[['song_popularity', 'acousticness',
       'danceability', 'energy', 'instrumentalness', 'key', 'liveness',
       'loudness', 'audio_mode', 'speechiness', 'tempo','audio_valence']] = songs_normalized

# %%
song_df_normalized.head()
# Out:
#                     song_name  song_popularity  acousticness  danceability  \
# 0  boulevard of broken dreams             0.73      0.005541      0.502533
# 1                  in the end             0.66      0.010340      0.549139
# 2           seven nation army             0.76      0.008202      0.746707
# 3                  by the way             0.74      0.026505      0.456940
# 4           how you remind me             0.56      0.000957      0.452888
#
#      energy  instrumentalness       key  liveness  loudness  audio_mode  \
# 0  0.682342          0.000029  0.727273  0.049226  0.859242         1.0
# 1  0.853697          0.000000  0.272727  0.099580  0.801948         0.0
# 2  0.462888          0.448345  0.000000  0.250333  0.766734         1.0
# 3  0.970940          0.003561  0.000000  0.093426  0.838352         1.0
# 4  0.766517          0.000000  0.909091  0.104707  0.835204         1.0
#
#    speechiness     tempo  audio_valence            artist_name
# 0     0.031243  0.689425       0.481707              green day
# 1     0.052922  0.434371       0.376016            linkin park
# 2     0.084166  0.511233       0.329268      the white stripes
# 3     0.113709  0.505303       0.201220  red hot chili peppers
# 4     0.033262  0.709856       0.583333             nickelback

# %%
# create feature matrix
song_features=song_df_normalized.set_index("song_name")
song_features.drop(["artist_name"],axis=1,inplace=True)
song_features.head()
# Out:
#                             song_popularity  acousticness  danceability  \
# song_name
# boulevard of broken dreams             0.73      0.005541      0.502533
# in the end                             0.66      0.010340      0.549139
# seven nation army                      0.76      0.008202      0.746707
# by the way                             0.74      0.026505      0.456940
# how you remind me                      0.56      0.000957      0.452888
#
#                               energy  instrumentalness       key  liveness  \
# song_name
# boulevard of broken dreams  0.682342          0.000029  0.727273  0.049226
# in the end                  0.853697          0.000000  0.272727  0.099580
# seven nation army           0.462888          0.448345  0.000000  0.250333
# by the way                  0.970940          0.003561  0.000000  0.093426
# how you remind me           0.766517          0.000000  0.909091  0.104707
#
#                             loudness  audio_mode  speechiness     tempo  \
# song_name
# boulevard of broken dreams  0.859242         1.0     0.031243  0.689425
# in the end                  0.801948         0.0     0.052922  0.434371
# seven nation army           0.766734         1.0     0.084166  0.511233
# by the way                  0.838352         1.0     0.113709  0.505303
# how you remind me           0.835204         1.0     0.033262  0.709856
#
#                             audio_valence
# song_name
# boulevard of broken dreams       0.481707
# in the end                       0.376016
# seven nation army                0.329268
# by the way                       0.201220
# how you remind me                0.583333

# %%
song_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13982 entries, boulevard of broken dreams to up to me
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   song_popularity   13982 non-null  float64
#  1   acousticness      13982 non-null  float64
#  2   danceability      13982 non-null  float64
#  3   energy            13982 non-null  float64
#  4   instrumentalness  13982 non-null  float64
#  5   key               13982 non-null  float64
#  6   liveness          13982 non-null  float64
#  7   loudness          13982 non-null  float64
#  8   audio_mode        13982 non-null  float64
#  9   speechiness       13982 non-null  float64
#  10  tempo             13982 non-null  float64
#  11  audio_valence     13982 non-null  float64
# dtypes: float64(12)
# memory usage: 1.4+ MB

# %%
song_features.values
# Out:
# array([[0.73      , 0.00554115, 0.50253293, ..., 0.03124336, 0.68942464,
#         0.48170732],
#        [0.66      , 0.01034035, 0.5491388 , ..., 0.05292242, 0.43437136,
#         0.37601626],
#        [0.76      , 0.0082018 , 0.74670719, ..., 0.08416578, 0.51123317,
#         0.32926829],
#        ...,
#        [0.23      , 0.85040145, 0.72847011, ..., 0.03772582, 0.53868883,
#         0.29065041],
#        [0.55      , 0.94879513, 0.49442756, ..., 0.03485654, 0.4377017 ,
#         0.32825203],
#        [0.6       , 0.91465855, 0.64842958, ..., 0.03209352, 0.37756172,
#         0.59044715]])

# %%
# Use cosine similarity based NN algorithm to calculate min distances and find similar songs
from scipy.sparse import csr_matrix

song_features_csr = csr_matrix(song_features.values)

# %%
song_features_csr
# Out:
# <13982x12 sparse matrix of type '<class 'numpy.float64'>'
# 	with 155885 stored elements in Compressed Sparse Row format>

# %%
from sklearn.neighbors import NearestNeighbors

model_nn = NearestNeighbors(metric='cosine',algorithm='brute')
model_nn.fit(song_features_csr)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine')

# %%
temp = song_features.copy()
temp.reset_index(inplace=True)
songsearch = 'fighter'
songsearch = songsearch.lower()
song_index = temp.index[temp['song_name'] ==songsearch].tolist()[0]


print(song_features.index[song_index])


distances,indices = model_nn.kneighbors(X = song_features.iloc[song_index,:].values.reshape(1,-1), n_neighbors=6)

for i in range(0, len(distances.flatten())):
    if i == 0:
        print("Recommendation for -",song_features.index[song_index],"-are: ")
    else:
        print(i,": ",song_features.index[indices.flatten()[i]])
# Out:
# fighter
# Recommendation for - fighter -are:
# 1 :  saigon velour
# 2 :  saigon velour (feat. snoop dogg & e-40)
# 3 :  the kill (bury me)
# 4 :  gypsy woman
# 5 :  bring me to life
